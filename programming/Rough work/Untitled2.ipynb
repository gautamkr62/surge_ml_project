# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\gauta\OneDrive - IIT Kanpur\Desktop\PROJECT\surge\Bijoy_work\Taiwan_2024\csv files\7_52_days_filtered_lat_lon_data.csv')

# %%
df
# Out:
#     Latitude  Longitude  14-Feb  15-Feb  16-Feb  17-Feb  18-Feb  19-Feb  \
# 0       25.0        120    47.4    33.6    35.0    35.2    39.3    39.3
# 1       25.0        120    56.0    39.5    39.5    42.2    48.7    49.6
# 2       25.0        120    61.7    45.9    50.7    48.5    57.9    60.1
# 3       25.0        120    69.3    54.2    66.3    56.9    67.8    68.7
# 4       25.0        120    79.1    64.5    83.8    65.0    76.7    76.3
# 5       25.0        120    89.5    75.0   102.1    72.3    84.9    81.0
# 6       25.0        120    97.2    83.7   114.6    79.1    90.4    81.3
# 7       25.0        120    96.6    86.3   115.8    81.4    89.9    78.2
# 8       25.0        120    93.0    88.2   114.8    80.2    87.8    74.9
# 9       25.0        120    90.5    91.7   114.8    81.8    89.0    75.8
# 10      25.0        120    85.4    91.9   104.8    82.9    90.9    78.8
# 11      25.0        120    84.4    89.0    98.8    84.2    90.5    78.1
# ...

# %%
total=[]
for i in range(14,30):
    column_name = f'{i}-Feb'
    print(column_name)
    df_temp = df[column_name]
    print(df_temp)
    for j in range(len(df_temp)):
        val = df_temp.iloc[j];
#         print(val)
        total.append(val)
# Out:
# 14-Feb
# 0     47.4
# 1     56.0
# 2     61.7
# 3     69.3
# 4     79.1
# 5     89.5
# 6     97.2
# 7     96.6
# 8     93.0
# 9     90.5
# 10    85.4
# 11    84.4
# 12    88.4
# 13    76.9
# 14    59.0
# 15    47.1
# 16    38.1
# 17    31.5
# 18    26.1
# 19    25.2
# 20    21.8
# 21    18.7
# 22    20.1
# 23    26.3
# Name: 14-Feb, dtype: float64
# 15-Feb
# 0     33.6
# 1     39.5
# 2     45.9
# 3     54.2
# 4     64.5
# 5     75.0
# 6     83.7
# 7     86.3
# 8     88.2
# 9     91.7
# 10    91.9
# 11    89.0
# 12    84.5
# 13    77.1
# 14    61.3
# 15    44.8
# 16    36.5
# 17    30.2
# 18    26.4
# 19    25.6
# 20    22.2
# 21    20.1
# 22    22.9
# 23    30.3
# Name: 15-Feb, dtype: float64
# 16-Feb
# 0      35.0
# 1      39.5
# 2      50.7
# 3      66.3
# 4      83.8
# 5     102.1
# 6     114.6
# 7     115.8
# 8     114.8
# 9     114.8
# 10    104.8
# 11     98.8
# 12     97.8
# 13     85.9
# 14     70.1
# 15     56.1
# 16     45.9
# 17     34.9
# 18     29.2
# 19     26.7
# ...

# %%
for i in range(1,32):
    column_name = f'0{i}-Mar'
    print(column_name)
    df_temp = df[column_name]
    print(df_temp)
    for j in range(len(df_temp)):
        val = df_temp.iloc[j];
#         print(val)
        total.append(val)
# Out:
# 01-Mar
# 0     30.6
# 1     39.6
# 2     49.9
# 3     62.1
# 4     76.9
# 5     89.3
# 6     94.4
# 7     95.0
# 8     93.7
# 9     90.5
# 10    87.2
# 11    83.8
# 12    77.7
# 13    67.1
# 14    53.3
# 15    39.6
# 16    29.4
# 17    25.6
# 18    24.0
# 19    20.8
# 20    19.0
# 21    18.6
# 22    21.1
# 23    28.0
# Name: 01-Mar, dtype: float64
# 02-Mar
# 0     35.8
# 1     44.2
# 2     53.1
# 3     61.3
# 4     68.8
# 5     76.0
# 6     82.6
# 7     85.1
# 8     86.6
# 9     90.5
# 10    92.1
# 11    89.3
# 12    84.3
# 13    73.6
# 14    61.0
# 15    49.5
# 16    37.9
# 17    32.4
# 18    29.3
# 19    24.5
# 20    21.4
# 21    18.3
# 22    17.3
# 23    23.4
# Name: 02-Mar, dtype: float64
# 03-Mar
# 0      31.7
# 1      39.5
# 2      49.5
# 3      60.7
# 4      71.5
# 5      81.4
# 6      91.2
# 7     100.7
# 8     106.4
# 9     102.6
# 10     96.9
# 11     98.0
# 12     92.8
# 13     76.6
# 14     58.9
# 15     46.9
# 16     36.6
# 17     30.3
# 18     29.6
# 19     26.1
# ...

# %%
len(total)
# Out:
# 384

# %%
df_main = pd.DataFrame(total)

# %%
df_main.to_csv("7_52_days_filtered_lat_lon_data_combined_on14-feb.csv")
